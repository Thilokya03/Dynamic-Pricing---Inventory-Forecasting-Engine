# %%
root_path = r"..\data\raw"

# %%
import pandas as pd

df_calendar = pd.read_csv(f"{root_path}\calendar.csv")
df_sales_eval = pd.read_csv(f"{root_path}\sales_train_evaluation.csv")
df_sales_val = pd.read_csv(f"{root_path}\sales_train_validation.csv")
df_sell_prices = pd.read_csv(f"{root_path}\sell_prices.csv")

# %%
print (df_calendar.sample(5),
df_sales_eval.sample(5),
df_sales_val.sample(5),
df_sell_prices.sample(5), sep="\n\n")
# Out:
#             date  wm_yr_wk    weekday  wday  month  year       d event_name_1  \
# 1422  2014-12-21     11447     Sunday     2     12  2014  d_1423          NaN
# 460   2012-05-03     11214   Thursday     6      5  2012   d_461          NaN
# 1207  2014-05-20     11416    Tuesday     4      5  2014  d_1208          NaN
# 1278  2014-07-30     11426  Wednesday     5      7  2014  d_1279          NaN
# 1385  2014-11-14     11441     Friday     7     11  2014  d_1386          NaN
#
#      event_type_1 event_name_2 event_type_2  snap_CA  snap_TX  snap_WI
# 1422          NaN          NaN          NaN        0        0        0
# 460           NaN          NaN          NaN        1        1        1
# 1207          NaN          NaN          NaN        0        0        0
# 1278          NaN          NaN          NaN        0        0        0
# 1385          NaN          NaN          NaN        0        0        1
#
#                                     id          item_id      dept_id  \
# ...
